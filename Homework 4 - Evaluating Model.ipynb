# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/course_lead_scoring.csv')

# %%
df.head()
# Out:
#     lead_source    industry  number_of_courses_viewed  annual_income  \
# 0      paid_ads         NaN                         1        79450.0
# 1  social_media      retail                         1        46992.0
# 2        events  healthcare                         5        78796.0
# 3      paid_ads      retail                         2        83843.0
# 4      referral   education                         3        85012.0
#
#   employment_status       location  interaction_count  lead_score  converted
# 0        unemployed  south_america                  4        0.94          1
# 1          employed  south_america                  1        0.80          0
# 2        unemployed      australia                  3        0.69          1
# 3               NaN      australia                  1        0.87          0
# 4     self_employed         europe                  3        0.62          1

# %%
df.isnull().sum()
# Out:
# lead_source                 128
# industry                    134
# number_of_courses_viewed      0
# annual_income               181
# employment_status           100
# location                     63
# interaction_count             0
# lead_score                    0
# converted                     0
# dtype: int64

# %%
categorical = ['location', 'employment_status', 'lead_source', 'industry']
numerical = ['number_of_courses_viewed', 'annual_income', 'interaction_count', 'lead_score']

# %%
# Fill missing values
df[categorical] = df[categorical].fillna('NA')   # categorical → 'NA'
df[numerical]   = df[numerical].fillna(0.0)      # numerical → 0.0

# %%
df.isnull().sum()
# Out:
# lead_source                 0
# industry                    0
# number_of_courses_viewed    0
# annual_income               0
# employment_status           0
# location                    0
# interaction_count           0
# lead_score                  0
# converted                   0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
df_train_full, df_test = train_test_split(df, test_size=0.25, random_state= 42)
df_train, df_val = train_test_split(df_train_full, test_size=0.33, random_state=42)

y_train = df_train.converted.values
y_val = df_val.converted.values

# %%
del df_train['converted']
del df_val['converted']

# %%
global_conversion = df_train_full.converted.mean()
global_conversion
# Out:
# 0.6049270072992701

# %%
from sklearn.metrics import mutual_info_score

# %%
df_train_full[categorical] = df_train_full[categorical].fillna('NaN')
def calculate_mi(series):
    return mutual_info_score(series, df_train_full.converted)      
df_mi = df_train_full[categorical].apply(calculate_mi)   
df_mi = df_mi.sort_values(ascending=False).to_frame(name='MI')   
df_mi
# Out:
#                          MI
# lead_source        0.026506
# employment_status  0.014230
# industry           0.011724
# location           0.003520

# %%
train_dict = df_train[categorical + numerical].to_dict(orient='records')
val_dict = df_val[categorical + numerical].to_dict(orient='records')

# %%
from sklearn.feature_extraction import DictVectorizer

dv = DictVectorizer(sparse=False)
dv.fit(train_dict)

X_train = dv.transform(train_dict)
X_val= dv.transform(val_dict)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
model.predict_proba(X_val)
# Out:
# array([[0.10673967, 0.89326033],
#        [0.37619142, 0.62380858],
#        [0.53489082, 0.46510918],
#        [0.49218551, 0.50781449],
#        [0.21997001, 0.78002999],
#        [0.290135  , 0.709865  ],
#        [0.19635677, 0.80364323],
#        [0.16519765, 0.83480235],
#        [0.48534246, 0.51465754],
#        [0.52484825, 0.47515175],
#        [0.04899321, 0.95100679],
#        [0.29202594, 0.70797406],
#        [0.55179413, 0.44820587],
#        [0.63637282, 0.36362718],
#        [0.34075268, 0.65924732],
#        [0.18940397, 0.81059603],
#        [0.73510634, 0.26489366],
#        [0.14808097, 0.85191903],
#        [0.24228811, 0.75771189],
#        [0.18570711, 0.81429289],
#        [0.67187972, 0.32812028],
#        [0.29168334, 0.70831666],
#        [0.2559343 , 0.7440657 ],
#        [0.52519066, 0.47480934],
#        [0.10948868, 0.89051132],
#        [0.6883047 , 0.3116953 ],
#        [0.32973638, 0.67026362],
#        [0.48194484, 0.51805516],
#        [0.48828909, 0.51171091],
#        [0.49444977, 0.50555023],
#        [0.46544781, 0.53455219],
#        [0.52123493, 0.47876507],
#        [0.2272753 , 0.7727247 ],
#        [0.2697086 , 0.7302914 ],
#        [0.5827704 , 0.4172296 ],
#        [0.18204662, 0.81795338],
#        [0.50851392, 0.49148608],
#        [0.48579309, 0.51420691],
#        [0.04172503, 0.95827497],
#        [0.21340613, 0.78659387],
#        [0.74353597, 0.25646403],
#        [0.05246684, 0.94753316],
#        [0.18250831, 0.81749169],
#        [0.39749081, 0.60250919],
#        [0.49631844, 0.50368156],
#        [0.51152022, 0.48847978],
#        [0.14171725, 0.85828275],
#        [0.64414542, 0.35585458],
#        [0.28804365, 0.71195635],
#        [0.61309688, 0.38690312],
#        [0.08163093, 0.91836907],
#        [0.39693412, 0.60306588],
#        [0.0245247 , 0.9754753 ],
#        [0.32393555, 0.67606445],
#        [0.47680037, 0.52319963],
#        [0.60364494, 0.39635506],
#        [0.29475681, 0.70524319],
#        [0.23491529, 0.76508471],
#        [0.30243794, 0.69756206],
#        [0.41652629, 0.58347371],
#        [0.39653509, 0.60346491],
#        [0.20906646, 0.79093354],
#        [0.37252777, 0.62747223],
#        [0.63043738, 0.36956262],
#        [0.27994273, 0.72005727],
#        [0.53897379, 0.46102621],
#        [0.05430219, 0.94569781],
#        [0.14772094, 0.85227906],
#        [0.52036337, 0.47963663],
#        [0.10695182, 0.89304818],
#        [0.13491355, 0.86508645],
#        [0.6033804 , 0.3966196 ],
#        [0.2512081 , 0.7487919 ],
#        [0.19202719, 0.80797281],
#        [0.44705294, 0.55294706],
#        [0.39331455, 0.60668545],
#        [0.32690515, 0.67309485],
#        [0.66097974, 0.33902026],
#        [0.37433342, 0.62566658],
#        [0.35623521, 0.64376479],
#        [0.41039987, 0.58960013],
#        [0.23600866, 0.76399134],
#        [0.16679811, 0.83320189],
#        [0.19504064, 0.80495936],
#        [0.33909217, 0.66090783],
#        [0.26567871, 0.73432129],
#        [0.55347858, 0.44652142],
#        [0.50481359, 0.49518641],
#        [0.38193109, 0.61806891],
#        [0.09069876, 0.90930124],
#        [0.4816836 , 0.5183164 ],
#        [0.48182344, 0.51817656],
#        [0.42820058, 0.57179942],
#        [0.36767404, 0.63232596],
#        [0.45685809, 0.54314191],
#        [0.16008681, 0.83991319],
#        [0.6412077 , 0.3587923 ],
#        [0.37937553, 0.62062447],
#        [0.44045644, 0.55954356],
#        [0.36603761, 0.63396239],
#        [0.49372237, 0.50627763],
#        [0.59483707, 0.40516293],
#        [0.3857902 , 0.6142098 ],
#        [0.71023919, 0.28976081],
#        [0.48205163, 0.51794837],
#        [0.06855069, 0.93144931],
#        [0.22272813, 0.77727187],
#        [0.55767402, 0.44232598],
#        [0.37527717, 0.62472283],
#        [0.12271628, 0.87728372],
#        [0.43800036, 0.56199964],
#        [0.18516345, 0.81483655],
#        [0.53125214, 0.46874786],
#        [0.27710811, 0.72289189],
#        [0.34473692, 0.65526308],
#        [0.20952201, 0.79047799],
#        [0.1313093 , 0.8686907 ],
#        [0.28554257, 0.71445743],
#        [0.27405904, 0.72594096],
#        [0.43723546, 0.56276454],
#        [0.40434989, 0.59565011],
#        [0.32127883, 0.67872117],
#        [0.46271433, 0.53728567],
#        [0.38550095, 0.61449905],
#        [0.35597435, 0.64402565],
#        [0.31878745, 0.68121255],
#        [0.48245501, 0.51754499],
#        [0.22302515, 0.77697485],
#        [0.23038076, 0.76961924],
#        [0.12109817, 0.87890183],
#        [0.31390656, 0.68609344],
#        [0.31657046, 0.68342954],
#        [0.2117421 , 0.7882579 ],
#        [0.47369009, 0.52630991],
#        [0.28902287, 0.71097713],
#        [0.05945288, 0.94054712],
#        [0.56783116, 0.43216884],
#        [0.08237345, 0.91762655],
#        [0.06077034, 0.93922966],
#        [0.26837648, 0.73162352],
#        [0.55721239, 0.44278761],
#        [0.21046164, 0.78953836],
#        [0.71420037, 0.28579963],
#        [0.49419665, 0.50580335],
#        [0.44729834, 0.55270166],
#        [0.54224037, 0.45775963],
#        [0.11122728, 0.88877272],
#        [0.31116353, 0.68883647],
#        [0.59854368, 0.40145632],
#        [0.268151  , 0.731849  ],
#        [0.037611  , 0.962389  ],
#        [0.23183334, 0.76816666],
#        [0.13725015, 0.86274985],
#        [0.62435607, 0.37564393],
#        [0.40483925, 0.59516075],
#        [0.57992404, 0.42007596],
#        [0.16233827, 0.83766173],
#        [0.50740106, 0.49259894],
#        [0.10866596, 0.89133404],
#        [0.44738632, 0.55261368],
#        [0.14509945, 0.85490055],
#        [0.1502973 , 0.8497027 ],
#        [0.2193191 , 0.7806809 ],
#        [0.21751644, 0.78248356],
#        [0.18477034, 0.81522966],
#        [0.20125836, 0.79874164],
#        [0.5078194 , 0.4921806 ],
#        [0.72974065, 0.27025935],
#        [0.39883888, 0.60116112],
#        [0.29024833, 0.70975167],
#        [0.12442363, 0.87557637],
#        [0.36829864, 0.63170136],
#        [0.14491102, 0.85508898],
#        [0.27655827, 0.72344173],
#        [0.24978007, 0.75021993],
#        [0.64975032, 0.35024968],
#        [0.09321136, 0.90678864],
#        [0.16736022, 0.83263978],
#        [0.5247809 , 0.4752191 ],
#        [0.24133916, 0.75866084],
#        [0.16552242, 0.83447758],
#        [0.28523257, 0.71476743],
#        [0.19115036, 0.80884964],
#        [0.3217126 , 0.6782874 ],
#        [0.37602265, 0.62397735],
#        [0.50244759, 0.49755241],
#        [0.55903466, 0.44096534],
#        [0.39540015, 0.60459985],
#        [0.62356098, 0.37643902],
#        [0.68462768, 0.31537232],
#        [0.44573759, 0.55426241],
#        [0.63394766, 0.36605234],
#        [0.2512367 , 0.7487633 ],
#        [0.24670708, 0.75329292],
#        [0.12376452, 0.87623548],
#        [0.41006241, 0.58993759],
#        [0.53049191, 0.46950809],
#        [0.16383685, 0.83616315],
#        [0.26628925, 0.73371075],
#        [0.63839799, 0.36160201],
#        [0.71216574, 0.28783426],
#        [0.06341414, 0.93658586],
#        [0.42009452, 0.57990548],
#        [0.31668739, 0.68331261],
#        [0.1268562 , 0.8731438 ],
#        [0.52766364, 0.47233636],
#        [0.32453972, 0.67546028],
#        [0.55095687, 0.44904313],
#        [0.36593139, 0.63406861],
#        [0.34246903, 0.65753097],
#        [0.28680949, 0.71319051],
#        [0.6988269 , 0.3011731 ],
#        [0.24404583, 0.75595417],
#        [0.32147648, 0.67852352],
#        [0.29914956, 0.70085044],
#        [0.3081974 , 0.6918026 ],
#        [0.39121911, 0.60878089],
#        [0.26195165, 0.73804835],
#        [0.41481371, 0.58518629],
#        [0.09897542, 0.90102458],
#        [0.16519955, 0.83480045],
#        [0.47655739, 0.52344261],
#        [0.08065652, 0.91934348],
#        [0.5599743 , 0.4400257 ],
#        [0.24688885, 0.75311115],
#        [0.46405806, 0.53594194],
#        [0.24677378, 0.75322622],
#        [0.12074627, 0.87925373],
#        [0.44598366, 0.55401634],
#        [0.37238287, 0.62761713],
#        [0.58095498, 0.41904502],
#        [0.54127187, 0.45872813],
#        [0.76704164, 0.23295836],
#        [0.11151582, 0.88848418],
#        [0.19122734, 0.80877266],
#        [0.31780939, 0.68219061],
#        [0.38180774, 0.61819226],
#        [0.33867743, 0.66132257],
#        [0.36330406, 0.63669594],
#        [0.51936927, 0.48063073],
#        [0.617171  , 0.382829  ],
#        [0.38160614, 0.61839386],
#        [0.10339366, 0.89660634],
#        [0.24028187, 0.75971813],
#        [0.31694876, 0.68305124],
#        [0.20713088, 0.79286912],
#        [0.23682207, 0.76317793],
#        [0.21285896, 0.78714104],
#        [0.37496026, 0.62503974],
#        [0.63566852, 0.36433148],
#        [0.16564731, 0.83435269],
#        [0.08342987, 0.91657013],
#        [0.33950293, 0.66049707],
#        [0.54387837, 0.45612163],
#        [0.08345371, 0.91654629],
#        [0.3269473 , 0.6730527 ],
#        [0.1896348 , 0.8103652 ],
#        [0.2657075 , 0.7342925 ],
#        [0.41897077, 0.58102923],
#        [0.20984211, 0.79015789],
#        [0.41231491, 0.58768509],
#        [0.18072223, 0.81927777],
#        [0.55739245, 0.44260755],
#        [0.37471552, 0.62528448],
#        [0.06465135, 0.93534865],
#        [0.37849509, 0.62150491],
#        [0.6019907 , 0.3980093 ],
#        [0.22857926, 0.77142074],
#        [0.1603994 , 0.8396006 ],
#        [0.14902816, 0.85097184],
#        [0.64346412, 0.35653588],
#        [0.67497697, 0.32502303],
#        [0.22519012, 0.77480988],
#        [0.71733831, 0.28266169],
#        [0.521118  , 0.478882  ],
#        [0.10591714, 0.89408286],
#        [0.54970738, 0.45029262],
#        [0.28755249, 0.71244751],
#        [0.13402038, 0.86597962],
#        [0.34637115, 0.65362885],
#        [0.35715756, 0.64284244],
#        [0.2511287 , 0.7488713 ],
#        [0.05597037, 0.94402963],
#        [0.53260748, 0.46739252],
#        [0.25907619, 0.74092381],
#        [0.14514548, 0.85485452],
#        [0.19280623, 0.80719377],
#        [0.65233203, 0.34766797],
#        [0.09418214, 0.90581786],
#        [0.26981535, 0.73018465],
#        [0.39222341, 0.60777659],
#        [0.63283063, 0.36716937],
#        [0.3615044 , 0.6384956 ],
#        [0.36503462, 0.63496538],
#        [0.42334027, 0.57665973],
#        [0.48884567, 0.51115433],
#        [0.2945723 , 0.7054277 ],
#        [0.29636129, 0.70363871],
#        [0.26791706, 0.73208294],
#        [0.28060014, 0.71939986],
#        [0.39769856, 0.60230144],
#        [0.51920155, 0.48079845],
#        [0.39135323, 0.60864677],
#        [0.40489481, 0.59510519],
#        [0.20398167, 0.79601833],
#        [0.2681696 , 0.7318304 ],
#        [0.24129474, 0.75870526],
#        [0.50090602, 0.49909398],
#        [0.39291221, 0.60708779],
#        [0.14206802, 0.85793198],
#        [0.11814842, 0.88185158],
#        [0.18356927, 0.81643073],
#        [0.52123521, 0.47876479],
#        [0.3329888 , 0.6670112 ],
#        [0.35429432, 0.64570568],
#        [0.14502181, 0.85497819],
#        [0.06836961, 0.93163039],
#        [0.29374419, 0.70625581],
#        [0.12432813, 0.87567187],
#        [0.36605959, 0.63394041],
#        [0.27715976, 0.72284024],
#        [0.1823876 , 0.8176124 ],
#        [0.474627  , 0.525373  ],
#        [0.44489596, 0.55510404],
#        [0.46839282, 0.53160718],
#        [0.40303657, 0.59696343],
#        [0.2786745 , 0.7213255 ],
#        [0.63692301, 0.36307699],
#        [0.08157812, 0.91842188],
#        [0.36063849, 0.63936151],
#        [0.16060036, 0.83939964],
#        [0.40340373, 0.59659627],
#        [0.08760583, 0.91239417],
#        [0.36683029, 0.63316971],
#        [0.26456185, 0.73543815],
#        [0.186011  , 0.813989  ],
#        [0.62373852, 0.37626148],
#        [0.17804086, 0.82195914],
#        [0.35676777, 0.64323223],
#        [0.31163038, 0.68836962],
#        [0.35709838, 0.64290162],
#        [0.57966886, 0.42033114],
#        [0.468434  , 0.531566  ],
#        [0.4118037 , 0.5881963 ],
#        [0.02744518, 0.97255482],
#        [0.16713428, 0.83286572],
#        [0.1449396 , 0.8550604 ],
#        [0.46437468, 0.53562532],
#        [0.31295915, 0.68704085],
#        [0.11807959, 0.88192041],
#        [0.10718972, 0.89281028],
#        [0.18485568, 0.81514432],
#        [0.22910419, 0.77089581],
#        [0.72602137, 0.27397863],
#        [0.15659853, 0.84340147],
#        [0.24241888, 0.75758112],
#        [0.35413717, 0.64586283],
#        [0.23286185, 0.76713815],
#        [0.2998083 , 0.7001917 ],
#        [0.38122336, 0.61877664],
#        [0.49640637, 0.50359363],
#        [0.56873987, 0.43126013]])

# %%
y_pred = model.predict_proba(X_val)[:, 1]

# %%
converted = y_pred > 0.5 
(y_val == converted).mean()
# Out:
# 0.7348066298342542

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# %%
auc_val = roc_auc_score(y_val, y_pred)
print("Validation AUC:", auc_val)
# Out:
# Validation AUC: 0.8250937391687935

# %%
thresholds = np.arange(0.0, 1.01, 0.01)  # 0.00 to 1.00 inclusive
results = []

for t in thresholds:
    y_pred = (y_pred >= t).astype(int)  # apply threshold
    precision = precision_score(y_val, y_pred, zero_division=0)
    recall = recall_score(y_val, y_pred, zero_division=0)
    auc = roc_auc_score(y_val, y_pred)  # AUC of the hard classification at this threshold
    results.append((t, precision, recall, auc))

# Display the results
for t, p, r, a in results:
    print(f"Threshold={t:.2f} | Precision={p:.4f} | Recall={r:.4f} | AUC={a:.4f}")
# Out:
# Threshold=0.00 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.01 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.02 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.03 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.04 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.05 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.06 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.07 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.08 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.09 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.10 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.11 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.12 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.13 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.14 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.15 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.16 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.17 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.18 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.19 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.20 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.21 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.22 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.23 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.24 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.25 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.26 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.27 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.28 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.29 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.30 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.31 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.32 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.33 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.34 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.35 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.36 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.37 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.38 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.39 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.40 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.41 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.42 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.43 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.44 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.45 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.46 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.47 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.48 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.49 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.50 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.51 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.52 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.53 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.54 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.55 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.56 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.57 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.58 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.59 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.60 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.61 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.62 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.63 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.64 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.65 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.66 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.67 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.68 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.69 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.70 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.71 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.72 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.73 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.74 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.75 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.76 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.77 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.78 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.79 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.80 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.81 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.82 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.83 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.84 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.85 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.86 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.87 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.88 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.89 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.90 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.91 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.92 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.93 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.94 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.95 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.96 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.97 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.98 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=0.99 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000
# Threshold=1.00 | Precision=0.5884 | Recall=1.0000 | AUC=0.5000

# %%
precision
# Out:
# 0.7052631578947368

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

thresholds = [i/100 for i in range(0, 101)]

for t in thresholds:
    y_pred = (y_pred >= t).astype(int)
    precision = precision_score(y_val, y_pred)
    recall = recall_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)

    print(f"Threshold={t:.2f} | Precision={precision:.4f} | Recall={recall:.4f} | F1={f1:.4f}")
# Out:
# Threshold=0.00 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.01 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.02 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.03 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.04 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.05 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.06 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.07 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.08 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.09 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.10 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.11 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.12 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.13 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.14 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.15 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.16 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.17 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.18 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.19 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.20 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.21 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.22 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.23 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.24 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.25 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.26 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.27 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.28 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.29 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.30 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.31 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.32 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.33 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.34 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.35 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.36 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.37 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.38 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.39 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.40 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.41 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.42 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.43 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.44 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.45 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.46 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.47 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.48 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.49 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.50 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.51 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.52 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.53 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.54 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.55 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.56 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.57 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.58 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.59 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.60 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.61 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.62 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.63 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.64 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.65 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.66 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.67 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.68 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.69 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.70 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.71 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.72 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.73 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.74 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.75 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.76 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.77 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.78 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.79 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.80 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.81 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.82 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.83 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.84 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.85 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.86 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.87 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.88 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.89 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.90 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.91 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.92 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.93 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.94 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.95 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.96 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.97 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.98 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=0.99 | Precision=0.5884 | Recall=1.0000 | F1=0.7409
# Threshold=1.00 | Precision=0.5884 | Recall=1.0000 | F1=0.7409

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=1)

scores = []

for train_index, val_index in kf.split(X_train):
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]  # ✅ no iloc

    model = LogisticRegression()
    model.fit(X_train_fold, y_train_fold)

    y_pred = model.predict_proba(X_val_fold)[:, 1]
    auc = roc_auc_score(y_val_fold, y_pred)
    scores.append(auc)

print("Scores:", scores)
print("Mean AUC:", np.mean(scores))
print("Standard Deviation:", np.std(scores))
# Out:
# Scores: [0.8871647509578543, 0.9159311562224184, 0.8990253411306043, 0.898497688751926, 0.893483231707317]
# Mean AUC: 0.8988204337540239
# Standard Deviation: 0.009563091988390284
# C:\Users\user\Anaconda3.1\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\user\Anaconda3.1\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\user\Anaconda3.1\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\user\Anaconda3.1\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\user\Anaconda3.1\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.model_selection import KFold, cross_val_score

C_values = [0.000001, 0.001, 1]

kf = KFold(n_splits=5, shuffle=True, random_state=42)

for C in C_values:
    model = LogisticRegression(solver='liblinear', C=C, max_iter=1000)
    scores = cross_val_score(model, X_train, y_train, cv=kf)
    print(f"C={C}  Mean={scores.mean():.3f}  Std={scores.std():.3f}")
# Out:
# C=1e-06  Mean=0.613  Std=0.051
# C=0.001  Mean=0.621  Std=0.055
# C=1  Mean=0.745  Std=0.032
